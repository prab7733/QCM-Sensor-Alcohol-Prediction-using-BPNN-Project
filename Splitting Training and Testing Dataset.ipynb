# %% [markdown]
# # Loading Libraries

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, accuracy_score, mean_squared_error,r2_score
from random import random
from math import exp
from random import randrange
from random import seed
from csv import reader

# %% [markdown]
# # Splitting Training and Testing

# %%
data = pd.read_csv('QCM10(cleaned).csv')
data.head()
# Out:
#    concentration1  concentration1_2  concentration2  concentration2_2  \
# 0          -11.98            -10.99          -19.12            -17.28
# 1          -12.15            -11.33          -22.33            -19.95
# 2          -12.58            -11.74          -26.67            -23.34
# 3          -13.79            -12.82          -30.56            -26.18
# 4          -15.73            -13.87          -34.54            -28.65
#
#    concentration3  concentration3_2  concentration4  concentration4_2  \
# 0          -33.13            -28.45          -48.83            -40.77
# 1          -39.82            -33.64          -56.90            -46.77
# 2          -46.48            -38.69          -65.95            -53.46
# 3          -52.30            -42.98          -73.81            -59.19
# 4          -57.44            -46.26          -80.37            -63.49
#
#    concentration5  concentration5_2  1-Octanol  1-Propanol  2-Butanol  \
# ...

# %%
#HOMA - Homeostasis Model Assessment
# x - data, y - target
y = data.concentration1
x = data.drop('concentration1', axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8)
x_train.head()
# Out:
#     concentration1_2  concentration2  concentration2_2  concentration3  \
# 1             -11.33          -22.33            -19.95          -39.82
# 12            -62.99          -94.15            -82.45         -133.24
# 15            -35.02          -66.13            -50.43          -90.29
# 17            -35.27          -66.60            -50.98          -80.79
# 14            -61.87          -95.09            -81.53         -128.23
#
#     concentration3_2  concentration4  concentration4_2  concentration5  \
# 1             -33.64          -56.90            -46.77          -73.32
# 12           -107.15         -165.33           -126.55         -204.60
# 15            -68.00         -101.74            -76.53         -117.67
# 17            -61.24          -93.34            -70.67         -106.18
# 14           -102.05         -156.31           -119.71         -187.95
#
#     concentration5_2  1-Octanol  1-Propanol  2-Butanol  2-propanol  \
# ...

# %%
x_train.shape
# Out:
# (20, 14)

# %%
x_train
# Out:
#     concentration1_2  concentration2  concentration2_2  concentration3  \
# 1             -11.33          -22.33            -19.95          -39.82
# 12            -62.99          -94.15            -82.45         -133.24
# 15            -35.02          -66.13            -50.43          -90.29
# 17            -35.27          -66.60            -50.98          -80.79
# 14            -61.87          -95.09            -81.53         -128.23
# 20            -41.67          -75.74            -57.70         -109.10
# 24            -41.87          -79.15            -60.58         -115.72
# 5             -38.66          -83.58            -57.33         -110.24
# 18            -34.97          -66.58            -50.93          -78.07
# 10            -61.86          -91.65            -81.02         -131.05
# 22            -43.04          -78.19            -60.05         -113.36
# 4             -13.87          -34.54            -28.65          -57.44
# ...

# %%
y_train.head()
# Out:
# 1    -12.15
# 12   -61.80
# 15   -44.10
# 17   -44.50
# 14   -62.34
# Name: concentration1, dtype: float64

# %%
y_train.shape
# Out:
# (20L,)

# %%
y_train
# Out:
# 1    -12.15
# 12   -61.80
# 15   -44.10
# 17   -44.50
# 14   -62.34
# 20   -52.22
# 24   -54.47
# 5    -58.41
# 18   -44.34
# 10   -59.41
# 22   -54.72
# 4    -15.73
# 21   -54.15
# 6    -59.68
# 13   -61.94
# 2    -12.58
# 16   -44.67
# 23   -54.54
# 8    -60.41
# 3    -13.79
# Name: concentration1, dtype: float64

# %%
x_test.shape
# Out:
# (5, 14)

# %%
x_test
# Out:
#     concentration1_2  concentration2  concentration2_2  concentration3  \
# 19            -35.17          -66.20            -50.42          -76.80
# 7             -40.73          -85.19            -59.47         -108.08
# 0             -10.99          -19.12            -17.28          -33.13
# 11            -62.92          -93.55            -82.39         -133.11
# 9             -39.88          -84.22            -57.58         -105.32
#
#     concentration3_2  concentration4  concentration4_2  concentration5  \
# 19            -58.26          -87.09            -65.55          -98.14
# 7             -76.43         -127.51            -92.88         -155.54
# 0             -28.45          -48.83            -40.77          -62.49
# 11           -107.27         -168.62           -128.94         -210.85
# 9             -73.36         -122.59            -88.28         -146.99
#
#     concentration5_2  1-Octanol  1-Propanol  2-Butanol  2-propanol  \
# ...

# %%
y_test.shape
# Out:
# (5L,)

# %%
y_test
# Out:
# 19   -44.80
# 7    -60.12
# 0    -11.98
# 11   -61.16
# 9    -60.87
# Name: concentration1, dtype: float64

# %%
df = pd.DataFrame(x_train, columns = ['concentration1_2','concentration2','concentration2_2','concentration3','concentration3_2','concentration4','concentration4_2','concentration5','concentration5_2'
                                     ,'1-Octanol','1-Propanol','2-Butanol','2-propanol','1-isobutanol'])
df.to_csv (r'C:\Users\User\Documents\UiTM\FSKM\CS259\Sem 4 Sub\ISP 560\ISP 560 Project\training.csv', index=False, header=True)
print(df)
train = pd.DataFrame(x_train, columns = ['concentration1_2','concentration2','concentration2_2','concentration3','concentration3_2','concentration4','concentration4_2','concentration5','concentration5_2'
                                     ,'1-Octanol','1-Propanol','2-Butanol','2-propanol','1-isobutanol'])
train.to_csv (r'C:\Users\User\Documents\UiTM\FSKM\CS259\Sem 4 Sub\ISP 560\ISP 560 Project\training(without header).csv', index=False, header=False)
# Out:
#     concentration1_2  concentration2  concentration2_2  concentration3  \
# 1             -11.33          -22.33            -19.95          -39.82
# 12            -62.99          -94.15            -82.45         -133.24
# 15            -35.02          -66.13            -50.43          -90.29
# 17            -35.27          -66.60            -50.98          -80.79
# 14            -61.87          -95.09            -81.53         -128.23
# 20            -41.67          -75.74            -57.70         -109.10
# 24            -41.87          -79.15            -60.58         -115.72
# 5             -38.66          -83.58            -57.33         -110.24
# 18            -34.97          -66.58            -50.93          -78.07
# 10            -61.86          -91.65            -81.02         -131.05
# 22            -43.04          -78.19            -60.05         -113.36
# 4             -13.87          -34.54            -28.65          -57.44
# ...

# %%
df2 = pd.DataFrame(x_test, columns = ['concentration1_2','concentration2','concentration2_2','concentration3','concentration3_2','concentration4','concentration4_2','concentration5','concentration5_2'
                                     ,'1-Octanol','1-Propanol','2-Butanol','2-propanol','1-isobutanol'])
df2.to_csv (r'C:\Users\User\Documents\UiTM\FSKM\CS259\Sem 4 Sub\ISP 560\ISP 560 Project\testing.csv', index=False, header=True)
print(df2)
test = pd.DataFrame(x_test, columns = ['concentration1_2','concentration2','concentration2_2','concentration3','concentration3_2','concentration4','concentration4_2','concentration5','concentration5_2'
                                     ,'1-Octanol','1-Propanol','2-Butanol','2-propanol','1-isobutanol'])
test.to_csv (r'C:\Users\User\Documents\UiTM\FSKM\CS259\Sem 4 Sub\ISP 560\ISP 560 Project\testing(without header).csv', index=False, header=False)
# Out:
#     concentration1_2  concentration2  concentration2_2  concentration3  \
# 19            -35.17          -66.20            -50.42          -76.80
# 7             -40.73          -85.19            -59.47         -108.08
# 0             -10.99          -19.12            -17.28          -33.13
# 11            -62.92          -93.55            -82.39         -133.11
# 9             -39.88          -84.22            -57.58         -105.32
#
#     concentration3_2  concentration4  concentration4_2  concentration5  \
# 19            -58.26          -87.09            -65.55          -98.14
# 7             -76.43         -127.51            -92.88         -155.54
# 0             -28.45          -48.83            -40.77          -62.49
# 11           -107.27         -168.62           -128.94         -210.85
# 9             -73.36         -122.59            -88.28         -146.99
#
#     concentration5_2  1-Octanol  1-Propanol  2-Butanol  2-propanol  \
# ...
